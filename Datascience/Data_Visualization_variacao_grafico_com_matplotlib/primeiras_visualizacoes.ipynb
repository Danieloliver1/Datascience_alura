# %% [markdown]
# ##Importando dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link = '/content/drive/MyDrive/Alura ciencia de dados/Datascience/Data_Visualization_variacao_grafico_com_matplotlib/dados/monitoramento_tempo.csv'

# %% [markdown]
# ##Importando Biliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# para que os gráficos do matplotlib seja automatico
# %matplotlib inline

# %%
df = pd.read_csv(link)

# %% [markdown]
# ##Visualizando dados

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.shape
# Out:
# (45253, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df.describe().round(4)
# Out:
#        temperatura     pressão    humidade  direção do vento  \
# count   45253.0000  45253.0000  45253.0000        45253.0000
# mean      284.9929   1019.2683     74.6716          189.8959
# std         7.4524      9.9428     19.0579          102.8765
# min       262.3700    968.0000     10.0000            0.0000
# 25%       279.8500   1014.0000     63.0000          107.0000
# 50%       284.3200   1019.0000     80.0000          198.0000
# 75%       289.4500   1025.0000     90.0000          289.0000
# max       312.5200   1056.0000    100.0000          360.0000
#
#        velocidade do vento
# count           45253.0000
# mean                2.0507
# std                 1.8408
# min                 0.0000
# 25%                 1.0000
# 50%                 1.0000
# 75%                 3.0000
# max                17.0000

# %%
# convertendo para tipo data
df['data'] = pd.to_datetime(df['data'])

# %%
df.data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 45253 entries, 0 to 45252
# Series name: data
# Non-Null Count  Dtype
# --------------  -----
# 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 353.7 KB

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/anatomy.png)

# %%
plt.figure(figsize = (15,6))
plt.plot( df.data, df.temperatura)
plt.title('Temperatura no tempo')
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %%
# adicionando titulo
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)
eixo.set_title('Temperatura x Tempo')
# Out:
# Text(0.5, 1.0, 'Temperatura x Tempo')

# %%
# adicionando titulo para o eixo x e y
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)
eixo.set_title('Temperatura x Tempo')
eixo.set_ylabel('Temperatura')
eixo.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
# adicionando tamanho da fonte do titulo do eixo x e y
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)
eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
# Out:
# Text(0.5, 0, 'Data')

# %%
# adicionando legenda
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)
eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %%
# mudando a cor
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet')

eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %% [markdown]
# Sobre cores do matplotlib
#
# ![](https://matplotlib.org/stable/_images/sphx_glr_named_colors_003.png)

# %% [markdown]
# ##Customizando nossas visualizações

# %%
# espessura da linhas
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet', lw = 0.9)

eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %%
# trocando o estilo da linha
# 'dotted' pontilhado
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet', lw = 0.9, ls = 'dotted')

eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %%
import datetime

fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet')

# colocando limite do eixo x
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %%
# adicionando uma grade

fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet')

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')
eixo.grid(True)

# %%
# adicionando marcadores
fig = plt.figure(figsize = (10,3))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura, color ='violet', marker = 'o')

# colocando limite do eixo x
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura x Tempo',fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)
eixo.legend(['temperatura'],loc='lower left')

# %% [markdown]
# # Criando Vários eixos

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2= fig.add_axes([0.1,0.5,0.4,0.4])

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2= fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_title('Temperatura no momento', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'best', fontsize = 15)

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2= fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_title('Temperatura no momento', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'best', fontsize = 15)


eixo2.plot(df.data,df.temperatura,color = 'mediumpurple')

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_title('Temperatura no momento', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'best', fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)


eixo2.plot(df.data,df.temperatura,color = 'mediumpurple')
#eixo2.set_title('Temperatura no momento')
eixo2.legend(['Temperatura'],loc = 'best')
eixo2.set_ylabel('Temperatura')
eixo2.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'upper left', fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)


eixo2.plot(df.data,df.temperatura,color = 'mediumpurple')
#eixo2.set_title('Temperatura no momento')
eixo2.legend(['Temperatura'],loc = 'best')
eixo2.set_ylabel('Temperatura')
eixo2.set_xlabel('Data')
# eixo2.grid(True)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_title('Temperatura em 2014', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'upper left', fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)


eixo2.plot(df.data,df.temperatura,color = 'mediumpurple')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.legend(['Temperatura'],loc = 'best')
eixo2.set_ylabel('Temperatura')
eixo2.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
# colocando limite no eixo y
fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.57,0.65,0.4,0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'paleturquoise')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em maio/2014', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'upper left', fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)


eixo2.plot(df.data,df.temperatura,color = 'mediumpurple')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize = 15, pad = 20)
eixo2.legend(['Temperatura'],loc = 'best')
eixo2.set_ylabel('Temperatura')
eixo2.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
# colocando filtro

fig = plt.figure(figsize = (10,5))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.57,0.65,0.4,0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color = 'palegreen')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em maio/2014', fontsize = 15, pad = 20)
eixo.legend(['Temperatura'],loc = 'upper left', fontsize = 15)
eixo.set_ylabel('Temperatura',fontsize = 10)
eixo.set_xlabel('Data',fontsize = 10)

azul_esquerda = df.data < datetime.datetime(2014,5,1)
azul_direita = df.data > datetime.datetime(2014,6,1)

eixo2.plot(df.data,df.temperatura,color = 'palegreen')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color ='b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color ='b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014')
eixo2.legend(['Temperatura'],loc = 'best')
eixo2.set_ylabel('Temperatura')
eixo2.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize = (10,4))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 20, pad = 15)
eixo.set_xlabel('Data', fontsize = 15)
eixo.set_ylabel('Temperatura', fontsize = 15)
eixo.legend(['Temperatura'])
eixo.grid(True)

# colocando uma linha de limite
eixo.axhline(max(df.temperatura), color ='k', linestyle = '--')
eixo.axhline(min(df.temperatura), color ='k', linestyle = '--')

# %%
# colocando uma anotação
fig = plt.figure(figsize = (10,4))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 20, pad = 15)
eixo.set_xlabel('Data', fontsize = 15)
eixo.set_ylabel('Temperatura', fontsize = 15)
eixo.legend(['Temperatura'])
eixo.grid(True)



# colocando uma linha de limite

#colocando o nome da linha máximo
x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)

eixo.annotate('Máximo', xy  = (x1,y1), fontsize=10)

#colocando o nome da linha mínimo
x2 = df.data[df.temperatura.idxmin()]
y2 = min(df.temperatura)

eixo.annotate('Mínimo', xy  = (x2,y2), fontsize=10)

# colocando uma linha de limite
eixo.axhline(max(df.temperatura), color ='k', linestyle = '--')
eixo.axhline(min(df.temperatura), color ='k', linestyle = '--')

# %%
# colocando uma anotação
fig = plt.figure(figsize = (10,4))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 20, pad = 15)
eixo.set_xlabel('Data', fontsize = 15)
eixo.set_ylabel('Temperatura', fontsize = 15)
eixo.legend(['Temperatura'])
eixo.grid(True)



# colocando uma linha de limite

#colocando o nome da linha máximo
x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)

# 7000 horas tamanho da seta
x2 = df.data[df.temperatura.idxmax() - 7000]
y2 = max(df.temperatura) - 5

eixo.annotate('Máximo', xy  = (x1,y1), fontsize=10, xytext = (x2,y2), arrowprops=dict(facecolor='k'))

# colocando uma linha de limite
eixo.axhline(max(df.temperatura), color ='k', linestyle = '--')
eixo.axhline(min(df.temperatura), color ='k', linestyle = '--')

# %%
# colocando uma anotação
fig = plt.figure(figsize = (10,4))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 20, pad = 15)
eixo.set_xlabel('Data', fontsize = 15)
eixo.set_ylabel('Temperatura', fontsize = 15)
eixo.legend(['Temperatura'])
eixo.grid(True)



# colocando uma linha de limite

#colocando o nome da linha máximo
x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)

# 7000 horas tamanho da seta
x2 = df.data[df.temperatura.idxmax() - 7000]
y2 = max(df.temperatura) - 5

eixo.annotate('Máximo', xy  = (x1,y1), fontsize=10, xytext = (x2,y2), arrowprops=dict(facecolor='k'))



#colocando o nome da linha mínino
x1 = df.data[df.temperatura.idxmin()]
y1 = min(df.temperatura)

# 7000 horas tamanho da seta
x2 = df.data[df.temperatura.idxmin() - 6000]
y2 = min(df.temperatura) + 5

eixo.annotate('Mínino', xy  = (x1,y1), fontsize=10, xytext = (x2,y2), arrowprops=dict(facecolor='k'))

# colocando uma linha de limite
eixo.axhline(max(df.temperatura), color ='k', linestyle = '--')
eixo.axhline(min(df.temperatura), color ='k', linestyle = '--')

# %% [markdown]
# ##Gráficos de barras

# %%
temperatura_por_dia_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Quarta', 'Quinta', 'Segunda', 'Sexta', 'Sábado', 'Terça']
temperatura_por_dia_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Quarta     284.998290
# Quinta     285.000643
# Segunda    284.985382
# Sexta      285.060886
# Sábado     285.003316
# Terça      284.892811
# Name: temperatura, dtype: float64

# %%
# plt.bar(temperatura_por_dia_semana.index, temperatura_por_dia_semana.values)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.bar(temperatura_por_dia_semana.index, temperatura_por_dia_semana)
eixo.set_title('Temperatura por dia da Semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da Semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura média')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_semana))

eixo.bar(indice, temperatura_por_dia_semana)
eixo.set_title('Temperatura por dia da Semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da Semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)

# colocando titulo no eixo x
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Quarta'),
#  Text(2, 0, 'Quinta'),
#  Text(3, 0, 'Segunda'),
#  Text(4, 0, 'Sexta'),
#  Text(5, 0, 'Sábado'),
#  Text(6, 0, 'Terça')]

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_semana))
cores = ['black', 'r', 'g', 'b' , 'yellow', 'orange', 'magenta']

# cor das bordas das barras edgecolor = 'b'
eixo.bar(indice, temperatura_por_dia_semana, color = cores, edgecolor = 'b')
eixo.set_title('Temperatura por dia da Semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da Semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)

# colocando titulo no eixo x
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Quarta'),
#  Text(2, 0, 'Quinta'),
#  Text(3, 0, 'Segunda'),
#  Text(4, 0, 'Sexta'),
#  Text(5, 0, 'Sábado'),
#  Text(6, 0, 'Terça')]

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_semana, labels = temperatura_por_dia_semana.index )
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

# porcentagem    autopct ='%.1f%%'
#
eixo.pie(temperatura_por_dia_semana, labels = temperatura_por_dia_semana.index, autopct ='%.1f%%' )
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

# porcentagem    autopct ='%.1f%%'

# explodir = [0.1,0,0,0,0,0.1,0.1] seperar
explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]

eixo.pie(temperatura_por_dia_semana, labels = temperatura_por_dia_semana.index, autopct ='%.1f%%', explode = explodir )
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# ##Gráfico de dispersão

# %%
link = '/content/drive/MyDrive/Alura ciencia de dados/Datascience/Data_Visualization_variacao_grafico_com_matplotlib/dados/iris.csv'
dados = pd.read_csv(link)

# %%
dados.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
fig = plt.figure(figsize = (10,6))
eixo = fig.add_axes([0,0,1,1])


eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 10, pad = 15)
eixo.set_xlabel('Comprimento da pétala', fontsize = 10)
eixo.set_ylabel('Largura da pétala', fontsize = 10)
# Out:
# Text(0, 0.5, 'Largura da pétala')

# %%
fig = plt.figure(figsize = (10,6))
eixo = fig.add_axes([0,0,1,1])


eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 10, pad = 15)
eixo.set_xlabel('Comprimento da pétala', fontsize = 10)
eixo.set_ylabel('Largura da pétala', fontsize = 10)
eixo.tick_params(labelsize = 13)

# %%
fig = plt.figure(figsize = (10,6))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}

for especie in dados['espécie'].unique():
  tmp = dados[dados['espécie']==especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color=cores[especie])

# eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 10, pad = 15)
eixo.set_xlabel('Comprimento da pétala', fontsize = 10)
eixo.set_ylabel('Largura da pétala', fontsize = 10)
eixo.tick_params(labelsize = 13)
eixo.legend(cores, fontsize = 12)

# %%
fig = plt.figure(figsize = (10,6))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}

for especie in dados['espécie'].unique():
  tmp = dados[dados['espécie']==especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color=cores[especie], marker  = marcadores[especie])


eixo.set_title('Gráfico de dispersão', fontsize = 10, pad = 15)
eixo.set_xlabel('Comprimento da pétala', fontsize = 10)
eixo.set_ylabel('Largura da pétala', fontsize = 10)
eixo.tick_params(labelsize = 13)
eixo.legend(cores, fontsize = 12)

# %%
fig = plt.figure(figsize = (10,6))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}

# s = 100 tamanho do marcador

for especie in dados['espécie'].unique():
  tmp = dados[dados['espécie']==especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color=cores[especie], marker  = marcadores[especie], s = 100)


eixo.set_title('Gráfico de dispersão', fontsize = 10, pad = 15)
eixo.set_xlabel('Comprimento da pétala', fontsize = 10)
eixo.set_ylabel('Largura da pétala', fontsize = 10)
eixo.tick_params(labelsize = 13)
eixo.legend(cores, fontsize = 12)

# %% [markdown]
# ##Gráfico Boxplot

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados['largura_pétala'])
eixo.set_title('Grafico de caixa', fontsize=12, pad=10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(1, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop(['espécie'],axis=1).values)
eixo.set_title('Grafico de caixa', fontsize=12, pad=10)
eixo.set_xticklabels(dados.drop(['espécie'],axis = 1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop(['espécie'],axis=1).values, patch_artist=True)
eixo.set_title('Grafico de caixa', fontsize=12, pad=10)
eixo.set_xticklabels(dados.drop(['espécie'],axis = 1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

cores = ['red','orange','blue', 'green']




caixas =  eixo.boxplot(dados.drop(['espécie'],axis=1).values, patch_artist=True)
eixo.set_title('Grafico de caixa', fontsize=12, pad=10)
eixo.set_xticklabels(dados.drop(['espécie'],axis = 1).columns)

for caixa, cor in zip(caixas['boxes'],cores):
  caixa.set(color = cor)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

cores = ['red','orange','blue', 'green']




caixas =  eixo.boxplot(dados.drop(['espécie'],axis=1).values, patch_artist=True)
eixo.set_title('Grafico de caixa', fontsize=12, pad=10)
eixo.set_xticklabels(dados.drop(['espécie'],axis = 1).columns)

for caixa, cor in zip(caixas['boxes'],cores):
  caixa.set(color = cor)

for outlier in caixas['fliers']:
  outlier.set(marker = 'x', markersize = 5)

# %% [markdown]
# ##Gráfico Histograma

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'])
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'],bins = 20)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'],bins = 20, orientation='horizontal')
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu,sigma), xy = (4.5,0.6),fontsize=12)
# Out:
# Text(4.5, 0.6, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate(f'$mu = {mu:.2f}$\n$sigma = {sigma:.2f}$', xy = (4.5,0.6),fontsize=12)
# Out:
# Text(4.5, 0.6, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu,sigma), xy = (4.5,0.6),fontsize=12)

# colocando reta

eixo.axvline(mu, color = 'r', linestyle='--')
eixo.annotate('média', xy=(mu-1.3,28),fontsize = 12)
# Out:
# Text(2.458666666666666, 28, 'média')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), xy = (5.5,0.6),fontsize=12)

# colocando reta

eixo.axvline(mu, color = 'r', linestyle='--')
eixo.annotate('média', xy=(mu-1,0.45),fontsize = 12)

eixo.axvline(dados['comprimento_pétala'].median(), color='b', linestyle='--')
eixo.annotate('médiana',xy = (dados['comprimento_pétala'].median(), 0.45), fontsize = 12)
# Out:
# Text(4.35, 0.45, 'médiana')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

df_iv = dados[dados['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'],bins = 20, density=True)
eixo.set_title('Iris Versicolor', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), xy = (4.8,1.2),fontsize=12)

# colocando reta

eixo.axvline(mu, color = 'r', linestyle='--')
eixo.annotate('média', xy=(mu-0.25,0.45),fontsize = 12)

eixo.axvline(df_iv['comprimento_pétala'].median(), color='b', linestyle='--')
eixo.annotate('médiana',xy = (df_iv['comprimento_pétala'].median(), 0.45), fontsize = 12)


# salvando a imagem
fig.savefig('histograma_iv.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = dados[dados['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'],bins = 20)
eixo.set_title('Iris Setosa', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), xy = (1.7,7),fontsize=12)

# colocando reta

eixo.axvline(mu, color = 'r', linestyle='--')
eixo.annotate('média', xy=(mu-0.2,13.5),fontsize = 12)

eixo.axvline(df_is['comprimento_pétala'].median(), color='b', linestyle='--')
eixo.annotate('médiana',xy = (df_is['comprimento_pétala'].median()+0.05,12), fontsize = 12,color='g')


# salvando a imagem
fig.savefig('histograma_is.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

df_ivc = dados[dados['espécie'] == 'Iris-virginica']

mu, sigma = df_ivc['comprimento_pétala'].mean(), df_ivc['comprimento_pétala'].std()

eixo.hist(df_ivc['comprimento_pétala'],bins = 20)
eixo.set_title('Iris Virginica', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize =15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), xy = (6.3,7),fontsize=12)

# colocando reta

eixo.axvline(mu, color = 'r', linestyle='--')
eixo.annotate('média', xy=(mu,8),fontsize = 12)

eixo.axvline(df_ivc['comprimento_pétala'].median(), color='b', linestyle='--')
eixo.annotate('médiana',xy = (df_ivc['comprimento_pétala'].median(),7), fontsize = 12,color='g')


# salvando a imagem
fig.savefig('histograma_ivc.png',bbox_inches='tight')

# %%
from PIL import Image

largura, altura = Image.open('/content/histograma_ivc.png').size
combinada = Image.new("RGB",( 3 *largura, altura))

intervalo = 0
for imagem in map(Image.open, ['/content/histograma_iv.png','/content/histograma_is.png','/content/histograma_ivc.png']):
  combinada.paste(imagem, (intervalo,0))
  intervalo += largura

combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1635x500>
