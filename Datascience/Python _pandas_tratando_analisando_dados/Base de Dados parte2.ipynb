# %% [markdown]
# #Relatório de Análise IV
#
# Seleção de Frequências

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

dados = pd.read_csv('/content/drive/MyDrive/Alura ciencia de dados/Datascience/Python Pandas tratando e analisando dados/.aluguel_residencial.csv',sep=';')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
# Selecione somente os imóveis classificados com tipo 'Apartamento'.

# criando bolleano de true para apartamentos
selecao = dados['Tipo'] == 'Apartamento'
n1 = dados[selecao].shape[0]
n1
# Out:
# 18780

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'.

selecao = (dados['Tipo'] =='Casa')   | (dados['Tipo'] =='Casa de Condomínio') | (dados['Tipo'] =='Casa de Vila')
n2 = dados[selecao].shape[0]
n2
# Out:
# 2210

# %%
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
# 60 >= Area <=100
selecao = (dados['Area'] >= 60) & (dados['Area'] <= 100)
n3 = dados[selecao].shape[0]
n3
# Out:
# 8424

# %%
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.

selecao = (dados['Quartos'] >= 4) & (dados['Valor'] < 2000)
n4 = dados[selecao].shape[0]
n4
# Out:
# 36

# %%
print
# Out:
# <function print>

# %%
# # outra forma de criar index e coluna

data = [(1, 2, 3, 4),
        (5, 6, 7, 8),
        (8, 10, 11, 12),
        (13, 14, 15, 16)]
df = pd.DataFrame(data, 'l1 l2 l3 l4'.split(), 'c1 c2 c3 c4'.split())

# %%
df
# Out:
#     c1  c2  c3  c4
# l1   1   2   3   4
# l2   5   6   7   8
# l3   8  10  11  12
# l4  13  14  15  16

# %%
df['c1']
# Out:
# l1     1
# l2     5
# l3     8
# l4    13
# Name: c1, dtype: int64

# %%
df[['c3','c1']]
# Out:
#     c3  c1
# l1   3   1
# l2   7   5
# l3  11   8
# l4  15  13

# %%
type(df[['c3','c1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[1:3]
# Out:
#     c1  c2  c3  c4
# l2   5   6   7   8
# l3   8  10  11  12

# %%
df[1:][['c3','c1']]
# Out:
#     c3  c1
# l2   7   5
# l3  11   8
# l4  15  13

# %%
# seleções pelo rotulo das linhas
df.loc['l3']
# Out:
# c1     8
# c2    10
# c3    11
# c4    12
# Name: l3, dtype: int64

# %%
df.loc[['l3','l2']]
# Out:
#     c1  c2  c3  c4
# l3   8  10  11  12
# l2   5   6   7   8

# %%
# iloc  faz o mesmo que o loc porem usa a posição

df.iloc[0,1]
# Out:
# 2

# %%
df.loc[['l3','l1'],['c4','c1']]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1

# %%
df
# Out:
#     c1  c2  c3  c4
# l1   1   2   3   4
# l2   5   6   7   8
# l3   8  10  11  12
# l4  13  14  15  16

# %%
df.iloc[[2,0],[3,0]]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1

# %% [markdown]
# #Relatório de Análise V
#
# Tratamento de Dados Faltantes

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
# dataframe booleano que retorna valores nulos se for nulo é verdadeiro se não for nulo é falso
dados.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False       False  False
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False  False
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 21821  False   False    False  False   False  False  False       False  False
# 21822  False   False    False  False   False  False  False       False  False
# 21823  False   False    False  False   False  False  False       False  False
# 21824  False   False    False  False   False  False  False       False  False
# 21825  False   False    False  False   False  False  False       False  False
#
# [21826 rows x 9 columns]

# %%
# dataframe booleano que retorna valores nulos se for nulo é false se não for nulo é verdadeiro
dados.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio  IPTU
# 0      True    True     True   True    True  True   True        True  True
# 1      True    True     True   True    True  True   True        True  True
# 2      True    True     True   True    True  True   True        True  True
# 3      True    True     True   True    True  True   True        True  True
# 4      True    True     True   True    True  True   True        True  True
# ...     ...     ...      ...    ...     ...   ...    ...         ...   ...
# 21821  True    True     True   True    True  True   True        True  True
# 21822  True    True     True   True    True  True   True        True  True
# 21823  True    True     True   True    True  True   True        True  True
# 21824  True    True     True   True    True  True   True        True  True
# 21825  True    True     True   True    True  True   True        True  True
#
# [21826 rows x 9 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21826 entries, 0 to 21825
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21826 non-null  object
#  1   Bairro      21826 non-null  object
#  2   Quartos     21826 non-null  int64
#  3   Vagas       21826 non-null  int64
#  4   Suites      21826 non-null  int64
#  5   Area        21826 non-null  int64
#  6   Valor       21826 non-null  float64
#  7   Condominio  21826 non-null  float64
#  8   IPTU        21826 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ MB

# %%
dados.Valor.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21821    False
# 21822    False
# 21823    False
# 21824    False
# 21825    False
# Name: Valor, Length: 21826, dtype: bool

# %%
dados[dados.Valor.isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
A = dados.shape[0]
dados.dropna(subset =['Valor'], inplace = True)
B = dados.shape[0]
A - B
# Out:
# 0

# %%
dados[dados.Valor.isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ## Tratamento de Dados faltantes (continuação)

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
selecao = (dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull())

# %%
A = dados.shape[0]
dados = dados[~selecao]
B = dados.shape[0]
A - B
# Out:
# 0

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
# atribuindo valores zeros

dados = dados.fillna({'Condominio':0,'IPTU':0})

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
dados[dados['IPTU'].isnull()].shape[0]
# Out:
# 0

# %%
dados.to_csv('/content/drive/MyDrive/Alura ciencia de dados/Datascience/Python Pandas tratando e analisando dados/.aluguel_residencial.csv',sep=';',index=False)

# %% [markdown]
# #Extra

# %%
data = [0.5, None, None, 0.52,0.54, None, None, 0.59,0.6, None, 0.7]
s=pd.Series(data)

# %%
s
# Out:
# 0     0.50
# 1      NaN
# 2      NaN
# 3     0.52
# 4     0.54
# 5      NaN
# 6      NaN
# 7     0.59
# 8     0.60
# 9      NaN
# 10    0.70
# dtype: float64

# %%
# passando valores nulos para zero.
s.fillna(0)
# Out:
# 0     0.50
# 1     0.00
# 2     0.00
# 3     0.52
# 4     0.54
# 5     0.00
# 6     0.00
# 7     0.59
# 8     0.60
# 9     0.00
# 10    0.70
# dtype: float64

# %%
# o metodo 'ffill pega o valor anterior nulo e coloca nele.
s.fillna(method = 'ffill')
# Out:
# 0     0.50
# 1     0.50
# 2     0.50
# 3     0.52
# 4     0.54
# 5     0.54
# 6     0.54
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %%
# o metodo 'bfill pega o valor posterior nulo e coloca nele.
s.fillna(method = 'bfill')
# Out:
# 0     0.50
# 1     0.52
# 2     0.52
# 3     0.52
# 4     0.54
# 5     0.59
# 6     0.59
# 7     0.59
# 8     0.60
# 9     0.70
# 10    0.70
# dtype: float64

# %%
# substitui valores vazio pela média
s.fillna(s.mean())
# Out:
# 0     0.500
# 1     0.575
# 2     0.575
# 3     0.520
# 4     0.540
# 5     0.575
# 6     0.575
# 7     0.590
# 8     0.600
# 9     0.575
# 10    0.700
# dtype: float64

# %%
# o metodo 'ffill pega o valor anterior nulo e coloca nele. colocando um limite
s.fillna(method = 'ffill', limit = 1)
# Out:
# 0     0.50
# 1     0.50
# 2      NaN
# 3     0.52
# 4     0.54
# 5     0.54
# 6      NaN
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %% [markdown]
# #Relátorio de Análise VI
#
# Criando novas Variáveis

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
# criando coluna valor bruto
dados['Valor Bruto'] = dados.Valor + dados.Condominio + dados.IPTU

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto
# 0      1700.0       500.0  60.0       2260.0
# ...

# %%
# valor de metro quadrado
dados['Valor m2'] = (dados.Valor / dados.Area).round(2)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2
# 0      1700.0       500.0  60.0       2260.0     42.50
# ...

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados.Area).round(2)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# ...

# %%
casa = ['casa', 'Casa de Condomínio','Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2  \
# ...

# %% [markdown]
# # Excluindo Variáveis

# %%
dados_aux = pd.DataFrame(dados[['Valor Bruto',	'Valor m2', 	'Valor Bruto m2', 	'Tipo Agregado']])

# %%
# excluindo coluna
del dados_aux['Valor Bruto']

# %%
dados_aux
# Out:
#        Valor m2  Valor Bruto m2 Tipo Agregado
# 0         42.50           56.50   Apartamento
# 1         70.00           70.00   Apartamento
# 2         53.33           80.67   Apartamento
# 3         16.67           21.46   Apartamento
# 4         26.00           32.36   Apartamento
# ...         ...             ...           ...
# 21821     12.86           20.54   Apartamento
# 21822     29.63           43.52   Apartamento
# 21823     23.08           33.85   Apartamento
# 21824     29.17           40.54   Apartamento
# 21825     42.86           53.71   Apartamento
#
# [21826 rows x 3 columns]

# %%
# Excluindo com o pop
dados_aux.pop('Valor Bruto m2')
# Out:
# 0        56.50
# 1        70.00
# 2        80.67
# 3        21.46
# 4        32.36
#          ...
# 21821    20.54
# 21822    43.52
# 21823    33.85
# 21824    40.54
# 21825    53.71
# Name: Valor Bruto m2, Length: 21826, dtype: float64

# %%
dados_aux
# Out:
#        Valor m2 Tipo Agregado
# 0         42.50   Apartamento
# 1         70.00   Apartamento
# 2         53.33   Apartamento
# 3         16.67   Apartamento
# 4         26.00   Apartamento
# ...         ...           ...
# 21821     12.86   Apartamento
# 21822     29.63   Apartamento
# 21823     23.08   Apartamento
# 21824     29.17   Apartamento
# 21825     42.86   Apartamento
#
# [21826 rows x 2 columns]

# %%
# Excluindo com drop
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis=1 , inplace=True)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# ...

# %% [markdown]
# #Extras Contadores

# %%
s= pd.Series(list('asdabhbjdasdflkm'))

# %%
s
# Out:
# 0     a
# 1     s
# 2     d
# 3     a
# 4     b
# 5     h
# 6     b
# 7     j
# 8     d
# 9     a
# 10    s
# 11    d
# 12    f
# 13    l
# 14    k
# 15    m
# dtype: object

# %%
s.unique()
# Out:
# array(['a', 's', 'd', 'b', 'h', 'j', 'f', 'l', 'k', 'm'], dtype=object)

# %%
s.value_counts()
# Out:
# a    3
# d    3
# s    2
# b    2
# h    1
# j    1
# f    1
# l    1
# k    1
# m    1
# dtype: int64

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# ...
