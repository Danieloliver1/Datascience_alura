# %% [markdown]
# #Relatório de Análise VII
#
# Criando Agrupamentos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

dados = pd.read_csv('/content/drive/MyDrive/Alura ciencia de dados/Datascience/Python Pandas tratando e analisando dados/.aluguel_residencial.csv',sep=';')

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 4       301.0  17.0

# %%
dados.Valor.mean()
# Out:
# 5046.172821405663

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados.Bairro.isin(bairros)
df = dados
dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
df['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
#               ...
# 13855          Bancários
# 15277         Cavalcanti
# 15280       Rio da Prata
# 15412      Cidade Jardim
# 16428        Coelho Neto
# Name: Bairro, Length: 152, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')
df = df.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 
# ...

# %%
grupo_bairro.head(5)
# Out:
#                    Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0             Quitinete       Copacabana        1      0       0    40
# 5    Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9           Apartamento       Copacabana        1      0       1    40
# 10            Quitinete       Copacabana        1      0       0    27
# 11          Apartamento       Copacabana        4      3       1   243
# 14          Apartamento  Barra da Tijuca        2      1       1    67
# 15          Apartamento           Tijuca        2      1       0   110
# 16   Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 18          Apartamento           Tijuca        2      1       0    78
# 19          Apartamento          Ipanema        3      1       1   125
# 20          Apartamento           Tijuca        1      0       0    48
# 21          Apartamento  Barra da Tijuca        3      3       1   175
# ...

# %%
for bairro, data in grupo_bairro:
  print(f'{bairro} -> {data.Valor.mean()}')
# Out:
# Barra da Tijuca -> 7069.552938130986
# Botafogo -> 8791.828178694159
# Copacabana -> 4126.677004538578
# Flamengo -> 4113.526610644258
# Ipanema -> 9352.001133786847
# Leblon -> 8746.344992050874
# Tijuca -> 2043.52

# %%
grupo_bairro.Valor.mean().round(2)
# Out:
# Bairro
# Barra da Tijuca    7069.55
# Botafogo           8791.83
# Copacabana         4126.68
# Flamengo           4113.53
# Ipanema            9352.00
# Leblon             8746.34
# Tijuca             2043.52
# Name: Valor, dtype: float64

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'],
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'],
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35],
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6],
                        'Aprovado': [True, False, False, True, True, True, False, False]},
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby('Sexo')

# %%
sexo = pd.DataFrame(sexo.Notas.mean().round(2))
sexo.columns = ['Media nota']
sexo
# Out:
#       Media nota
# Sexo
# F           5.82
# M           7.12

# %% [markdown]
# #Estatísiticas Descritivas

# %%
grupo_bairro.Valor.describe().round(2)
# Out:
#                   count     mean        std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55   11874.15   800.0  2500.0  4500.0   8500.0
# Botafogo          873.0  8791.83  152202.41   700.0  2200.0  3000.0   4350.0
# Copacabana       2644.0  4126.68    3611.41   100.0  2000.0  3000.0   4800.0
# Flamengo          714.0  4113.53    3839.13   800.0  1900.0  2900.0   4975.0
# Ipanema          1764.0  9352.00    8219.72  1200.0  4500.0  7000.0  11000.0
# Leblon           1258.0  8746.34    7004.04   100.0  4500.0  7000.0  10500.0
# Tijuca           1100.0  2043.52    1664.34   750.0  1500.0  1800.0   2300.0
#
#                        max
# Bairro
# Barra da Tijuca   600000.0
# Botafogo         4500000.0
# Copacabana         35000.0
# Flamengo           35000.0
# Ipanema            90000.0
# Leblon            100000.0
# Tijuca             45000.0

# %%
grupo_bairro.Valor.aggregate(['min','max','sum']).rename(columns = {'min':'Mínimo', 'max':'Máximo'})
# Out:
#                  Mínimo     Máximo         sum
# Bairro
# Barra da Tijuca   800.0   600000.0  27309683.0
# Botafogo          700.0  4500000.0   7675266.0
# Copacabana        100.0    35000.0  10910934.0
# Flamengo          800.0    35000.0   2937058.0
# Ipanema          1200.0    90000.0  16496930.0
# Leblon            100.0   100000.0  11002902.0
# Tijuca            750.0    45000.0   2247872.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure',figsize = (20,10))

# %%
fig = df.Valor.std().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por bairro')
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por bairro')

# %%
df.head()
# Out:
#               Tipo              Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0        Quitinete          Copacabana        1      0       0    40  1700.0
# 1             Casa     Jardim Botânico        2      0       1   100  7000.0
# 2      Apartamento              Centro        1      0       0    15   800.0
# 3      Apartamento        Higienópolis        1      0       0    48   800.0
# 4      Apartamento            Cachambi        2      0       0    50  1300.0
# ...            ...                 ...      ...    ...     ...   ...     ...
# 20710         Casa              Cocotá        3      1       3   300  4000.0
# 20876  Apartamento  Barra de Guaratiba        3      2       1   145  4500.0
# 21292         Casa              Jacaré        2      1       0    80  1500.0
# 21454         Casa             Turiaçu        2      1       0    45   700.0
# 21733  Apartamento     Parada de Lucas        2      1       0    55   900.0
#
#        Condominio    IPTU
# ...

# %%
iptu = pd.DataFrame(dados)
dados_iptu = iptu.groupby('Bairro')['IPTU'].mean()

# %%
dados_iptu.head()
# Out:
# Bairro
# Barra da Tijuca    1510.805592
# Botafogo            260.388316
# Copacabana          383.261346
# Flamengo            292.768908
# Ipanema             759.939909
# Name: IPTU, dtype: float64

# %%
#fig = plot.bar(x = dados_iptu.Bairro,y= dados_iptu.IPTU.mean(),color = 'blue')
fig, ax = plt.subplots()
ax.bar(x=dados_iptu.index, height=dados_iptu, color='blue')

#fig.set_ylabel('Valor do Aluguel')
#fig.set_title('Valor Médio do Aluguel por bairro')
# Out:
# <BarContainer object of 7 artists>

# %%
dados
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete       Copacabana        1      0       0    40
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9             Apartamento       Copacabana        1      0       1    40
# 10              Quitinete       Copacabana        1      0       0    27
# 11            Apartamento       Copacabana        4      3       1   243
# ...                   ...              ...      ...    ...     ...   ...
# 21816         Apartamento           Leblon        3      0       1    80
# 21817         Apartamento          Ipanema        3      1       2   150
# 21818         Apartamento           Tijuca        1      0       0    28
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 21825         Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU
# 0       1700.0       500.0    60.0
# ...

# %%
# Tabela de frequência
# 1 e 2
# 3 e 4
# 5 e 6
# 7 ou mais

classes = [0, 2, 4, 6, 100]

# %%
quartos = pd.cut(dados.Quartos, classes)

# %%
quartos
# Out:
# 0        (0, 2]
# 5        (4, 6]
# 9        (0, 2]
# 10       (0, 2]
# 11       (2, 4]
#           ...
# 21816    (2, 4]
# 21817    (2, 4]
# 21818    (0, 2]
# 21820    (4, 6]
# 21825    (0, 2]
# Name: Quartos, Length: 12216, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
pd.value_counts(quartos)
# Out:
# (2, 4]      6233
# (0, 2]      5406
# (4, 6]       463
# (6, 100]      29
# Name: Quartos, dtype: int64

# %%
labels = ['1 e 2 qurtos',' 3 e 4 quartos', '5 e 6 quartos', '7 quartos ou mais']

# %%
quartos = pd.cut(dados.Quartos,classes, labels= labels)

# %%
pd.value_counts(quartos)
# Out:
#  3 e 4 quartos       6233
# 1 e 2 qurtos         5406
# 5 e 6 quartos         463
# 7 quartos ou mais      29
# Name: Quartos, dtype: int64

# %%
quartos = pd.cut(dados.Quartos,classes, labels= labels, include_lowest=True)

# %%
pd.value_counts(quartos)
# Out:
#  3 e 4 quartos       6233
# 1 e 2 qurtos         5491
# 5 e 6 quartos         463
# 7 quartos ou mais      29
# Name: Quartos, dtype: int64
