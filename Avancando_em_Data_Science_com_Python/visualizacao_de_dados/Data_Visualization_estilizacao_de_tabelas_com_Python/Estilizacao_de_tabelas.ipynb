# %% [markdown]
# # Coleta e preparação de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link='/content/drive/MyDrive/Datascience_alura/01_Alura_ciencia_e_dados/Avancando_em_Data_Science_com_Python/Data_Visualization_estilizacao_de_tabelas_com_Python/relatorio_vendas.csv'

# %%
import pandas as pd

df = pd.read_csv(link)
df.head()
# Out:
#   data_pedido      modo_envio       nome_cliente segmento_cliente  \
# 0  2018-11-09       Econômica    Thiago Silveira              B2C
# 1  2018-11-09       Econômica    Thiago Silveira              B2C
# 2  2018-06-13       Econômica      Giovanna Lima              B2B
# 3  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 4  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
#
#            cidade          estado   regiao             departamento  \
# 0  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 1  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 2  Rio de Janeiro  Rio de Janeiro  Sudeste  Jardinagem e paisagismo
# 3   Foz do Iguaçu          Paraná      Sul  Materiais de construção
# 4   Foz do Iguaçu          Paraná      Sul  Jardinagem e paisagismo
#
#                 tipo_produto   vendas  quantidade    lucro
# 0               encanamentos   890.66           2   142.51
# ...

# %%
df.head(20)
# Out:
#    data_pedido      modo_envio       nome_cliente segmento_cliente  \
# 0   2018-11-09       Econômica    Thiago Silveira              B2C
# 1   2018-11-09       Econômica    Thiago Silveira              B2C
# 2   2018-06-13       Econômica      Giovanna Lima              B2B
# 3   2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 4   2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 5   2016-06-10  Entrega padrão        Sophia Dias              B2C
# 6   2016-06-10  Entrega padrão        Sophia Dias              B2C
# 7   2016-06-10  Entrega padrão        Sophia Dias              B2C
# 8   2016-06-10  Entrega padrão        Sophia Dias              B2C
# 9   2016-06-10  Entrega padrão        Sophia Dias              B2C
# 10  2016-06-10  Entrega padrão        Sophia Dias              B2C
# 11  2016-06-10  Entrega padrão        Sophia Dias              B2C
# 12  2019-04-16  Entrega padrão    Marina Carvalho              B2C
# ...

# %%
df['data_pedido'] = pd.to_datetime(df['data_pedido'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_pedido       8940 non-null   datetime64[ns]
#  1   modo_envio        8940 non-null   object
#  2   nome_cliente      8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   cidade            8940 non-null   object
#  5   estado            8940 non-null   object
#  6   regiao            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_produto      8940 non-null   object
#  9   vendas            8940 non-null   float64
#  10  quantidade        8940 non-null   int64
#  11  lucro             8940 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 838.2+ KB

# %% [markdown]
# # Missão 1: Time de vendas
#
# Precisamos construir uma visualização para indicar os **10 maiores clientes por total de venda**.
#
# Com isso, a equipe de vendas pode pensar em estratégias para manter esses clientes comprando em nossa loja.

# %%
df_cliente_vendas = df.groupby(['nome_cliente'])['vendas'].sum().nlargest(10).copy()

df_cliente_vendas = df_cliente_vendas.reset_index()
df_cliente_vendas
# Out:
#             nome_cliente    vendas
# 0    Maria Luiza Almeida  64777.54
# 1        Ana Julia Pinto  51398.95
# 2            Ryan Farias  48178.94
# 3         Heitor da Mata  47610.85
# 4  Maria Clara Gonçalves  46946.42
# 5         Raquel Freitas  44826.26
# 6             Davi Ramos  43769.21
# 7            Amanda Melo  42354.27
# 8         Alexia Ribeiro  41238.84
# 9         Calebe Ribeiro  41056.70

# %%
df_cliente_vendas.columns = ['Clientes','Vendas']
df_cliente_vendas['Ranque'] = df_cliente_vendas.index + 1

# %%
df_cliente_vendas
# Out:
#                 Clientes    Vendas  Ranque
# 0    Maria Luiza Almeida  64777.54       1
# 1        Ana Julia Pinto  51398.95       2
# 2            Ryan Farias  48178.94       3
# 3         Heitor da Mata  47610.85       4
# 4  Maria Clara Gonçalves  46946.42       5
# 5         Raquel Freitas  44826.26       6
# 6             Davi Ramos  43769.21       7
# 7            Amanda Melo  42354.27       8
# 8         Alexia Ribeiro  41238.84       9
# 9         Calebe Ribeiro  41056.70      10

# %%
df_cliente_vendas.set_index('Ranque', inplace = True)

# %%
df_cliente_vendas
# Out:
#                      Clientes    Vendas
# Ranque
# 1         Maria Luiza Almeida  64777.54
# 2             Ana Julia Pinto  51398.95
# 3                 Ryan Farias  48178.94
# 4              Heitor da Mata  47610.85
# 5       Maria Clara Gonçalves  46946.42
# 6              Raquel Freitas  44826.26
# 7                  Davi Ramos  43769.21
# 8                 Amanda Melo  42354.27
# 9              Alexia Ribeiro  41238.84
# 10             Calebe Ribeiro  41056.70

# %%
s = df_cliente_vendas.style
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_036ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_036ec_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_036ec_level0_col1" class="col_heading level0 col1" >Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranque</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_036ec_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_036ec_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_036ec_row0_col1" class="data row0 col1" >64777.540000</td>
#     </tr>
#     <tr>
#       <th id="T_036ec_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_036ec_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
# ...

# %%
s.format({'Vendas':'R$ {:,.2f}'})
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_036ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_036ec_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_036ec_level0_col1" class="col_heading level0 col1" >Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranque</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_036ec_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_036ec_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_036ec_row0_col1" class="data row0 col1" >R$ 64,777.54</td>
#     </tr>
#     <tr>
#       <th id="T_036ec_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_036ec_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
# ...

# %% [markdown]
# # Missão 2: Time comercial
#
# Precisamos construir uma visualização que permita associar o **total ganho em vendas e o total lucrado por tipo de produto**.
#
# Isso vai permitir que o time comercial possa focar em estratégias para alavancar as rendas que ganham com cada tipo de produto vendido na loja.

# %%
df_vendas_lucro = df.groupby(['tipo_produto'])[['vendas','lucro']].sum()

# %%
df_vendas_lucro.index.name = 'tipo produto'

# %%
df_vendas_lucro
# Out:
#                                vendas      lucro
# tipo produto
# decoração de jardim          82680.87   19880.86
# encanamentos                373224.39  -11243.39
# equipamentos de limpeza     542304.55   17448.30
# ferramentas                 995159.43   82042.91
# ferramentas automotivas     502109.33  126660.54
# ferramentas de jardinagem   648880.47  106408.80
# fertilizantes                53144.55   22509.86
# iluminação                  275229.82   40531.09
# materiais de paisagismo     150552.80   -3823.67
# materiais de revestimento   629656.41  -57737.23
# mobiliário de exterior      328932.37   53569.57
# mudas                         8811.69    2762.88
# pesticidas                  244958.41  106688.03
# peças de reposição          486907.88  182297.32
# pneus                      1022430.50  134923.09
# sementes                     39980.49   17730.06
# vasos                       696045.39   67887.28

# %%
estilo_produto = df_vendas_lucro.style
estilo_produto
# Out:
# <style type="text/css">
# </style>
# <table id="T_50db1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50db1_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_50db1_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50db1_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_50db1_row0_col0" class="data row0 col0" >82680.870000</td>
#       <td id="T_50db1_row0_col1" class="data row0 col1" >19880.860000</td>
#     </tr>
#     <tr>
#       <th id="T_50db1_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_50db1_row1_col0" class="data row1 col0" >373224.390000</td>
# ...

# %%
estilo_produto.format('R$ {:,.2f}').highlight_max(color='lightgreen')\
              .highlight_min(color='#F16165')
# Out:
# <style type="text/css">
# #T_50db1_row9_col1, #T_50db1_row11_col0 {
#   background-color: #F16165;
# }
# #T_50db1_row13_col1, #T_50db1_row14_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50db1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50db1_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_50db1_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50db1_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_50db1_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_50db1_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
# ...

# %%
estilo_produto.format('R$ {:,.2f}').background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_50db1_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_50db1_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_50db1_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_50db1_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_50db1_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_50db1_row2_col1, #T_50db1_row10_col0, #T_50db1_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_50db1_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_50db1_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_50db1_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_50db1_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_50db1_row5_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_50db1_row5_col1, #T_50db1_row12_col1 {
# ...

# %%
cabecalho = {
    'selector':'th',
    'props':'font-weight: bold; font-family: Arial;text-align: center; text-tranform: capitalize;',      # propriedades ex:. tamanho o tipo da fonte.
}

# %%
estilo_produto.set_table_styles([cabecalho], overwrite = False)
# Out:
# <style type="text/css">
# #T_50db1 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-tranform: capitalize;
# }
# #T_50db1_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_50db1_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_50db1_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_50db1_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_50db1_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_50db1_row2_col1, #T_50db1_row10_col0, #T_50db1_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_50db1_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_50db1_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_50db1_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_50db1_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_50db1_row5_col0 {
# ...

# %% [markdown]
# # Missão 3: Time de logística
#
# Precisamos construir uma visualização que permita entender a **distribuição de pedidos por região do Brasil**.
#
# Isso vai permitir que o time logística entenda onde é mais interessante focar material e pessoas.

# %%
df_regiao = pd.DataFrame(df['regiao'].value_counts())
df_regiao.columns = ['N° pedidos']
df_regiao
# Out:
#               N° pedidos
# regiao
# Sudeste             4470
# Nordeste            2075
# Centro-Oeste         983
# Norte                779
# Sul                  633

# %%
df_regiao.index.name = 'Regiao'
df_regiao
# Out:
#               N° pedidos
# Regiao
# Sudeste             4470
# Nordeste            2075
# Centro-Oeste         983
# Norte                779
# Sul                  633

# %%
porcentagem = df_regiao['N° pedidos'].to_numpy()
porcentagem = 100 * porcentagem/porcentagem.sum()
porcentagem
# Out:
# array([50.        , 23.21029083, 10.99552573,  8.71364653,  7.08053691])

# %%
df_regiao['Porcentagem regiao'] = porcentagem
df_regiao
# Out:
#               N° pedidos  Porcentagem regiao
# Regiao
# Sudeste             4470           50.000000
# Nordeste            2075           23.210291
# Centro-Oeste         983           10.995526
# Norte                779            8.713647
# Sul                  633            7.080537

# %%
estilo_regiao = df_regiao.style
estilo_regiao
# Out:
# <style type="text/css">
# </style>
# <table id="T_6470f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6470f_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_6470f_level0_col1" class="col_heading level0 col1" >Porcentagem regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6470f_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_6470f_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_6470f_row0_col1" class="data row0 col1" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6470f_level0_row1" class="row_heading level0 row1" >Nordeste</th>
#       <td id="T_6470f_row1_col0" class="data row1 col0" >2075</td>
# ...

# %%
cabecalho = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: right; background-color: white, color: black'
}
celulas = {
    'selector': 'td',
    'props': 'background-color: white; color: black'
}

estilo_regiao.set_table_styles([cabecalho,celulas])
# Out:
# <style type="text/css">
# #T_6470f th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white, color;
# }
# #T_6470f td {
#   background-color: white;
#   color: black;
# }
# </style>
# <table id="T_6470f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6470f_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_6470f_level0_col1" class="col_heading level0 col1" >Porcentagem regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6470f_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_6470f_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_6470f_row0_col1" class="data row0 col1" >50.000000</td>
#     </tr>
#     <tr>
# ...

# %%
estilo_regiao.format({'Porcentagem regiao':'{:.2f} %'})\
             .bar(subset='Porcentagem regiao', vmin=0, vmax=100.0, color='#9CD33B')
# Out:
# <style type="text/css">
# #T_6470f th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white, color;
# }
# #T_6470f td {
#   background-color: white;
#   color: black;
# }
# #T_6470f_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 50.0%, transparent 50.0%);
# }
# #T_6470f_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 23.2%, transparent 23.2%);
# }
# #T_6470f_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 11.0%, transparent 11.0%);
# }
# #T_6470f_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 8.7%, transparent 8.7%);
# }
# #T_6470f_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 7.1%, transparent 7.1%);
# }
# </style>
# <table id="T_6470f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
# Exercicios

# Dados da tabela
data = {
    'Ranking': [1, 2, 3, 4, 5],
    'Ano': [2009, 2019, 2022, 1997, 2015],
    'Filme': ['Avatar', 'Avengers: Endgame', 'Avatar: The Way of Water', 'Titanic', 'Star Wars: The Force Awakens'],
    'Distribuidor': ['20th Century Fox', 'Walt Disney Studios Motion Pictures', '20th Century Studios', 'Paramount Pictures / 20th Century Fox', 'Walt Disney Studios Motion Pictures'],
    'Bilheteria (US$)': [2923706026.0, 2799439100.0, 2319380773.0, 2264577439.0, 2071310218.0]
}

# Criando o DataFrame
df1 = pd.DataFrame(data)
df1 = df1.set_index('Ranking')
df1

# Criando o Styler
estilo = df1.style.format({'Bilheteria (US$)':'{:,.0f}'})
estilo
# Out:
# <style type="text/css">
# </style>
# <table id="T_2cbfb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cbfb_level0_col0" class="col_heading level0 col0" >Ano</th>
#       <th id="T_2cbfb_level0_col1" class="col_heading level0 col1" >Filme</th>
#       <th id="T_2cbfb_level0_col2" class="col_heading level0 col2" >Distribuidor</th>
#       <th id="T_2cbfb_level0_col3" class="col_heading level0 col3" >Bilheteria (US$)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cbfb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2cbfb_row0_col0" class="data row0 col0" >2009</td>
# ...

# %%
cabecalho = {
    'selector': 'th',
    'props': 'font-family: Helvetica; color: #dddd55; background-color: #34495E; text-align: center;'
}

celulas = {
    'selector': 'td',
    'props': 'font-family: Helvetica; color: white; background-color: #34495E; text-align: left;'
}

estilo.set_table_styles([cabecalho, celulas])
# Out:
# <style type="text/css">
# #T_2cbfb th {
#   font-family: Helvetica;
#   color: #dddd55;
#   background-color: #34495E;
#   text-align: center;
# }
# #T_2cbfb td {
#   font-family: Helvetica;
#   color: white;
#   background-color: #34495E;
#   text-align: left;
# }
# </style>
# <table id="T_2cbfb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cbfb_level0_col0" class="col_heading level0 col0" >Ano</th>
#       <th id="T_2cbfb_level0_col1" class="col_heading level0 col1" >Filme</th>
#       <th id="T_2cbfb_level0_col2" class="col_heading level0 col2" >Distribuidor</th>
#       <th id="T_2cbfb_level0_col3" class="col_heading level0 col3" >Bilheteria (US$)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
# ...

# %% [markdown]
# # Missão 4: Time de logística
#
# Novamente o time de logística deseja repensar sua estrutura e organização de fornecimento de produtos e para isso, foi pensada em uma visualização que permita identificar padrão de **quantidade de produtos solicitados por mês por departamento**.

# %%
df_meses = df.copy()
df_meses = df_meses.sort_values('data_pedido')
df_meses
# Out:
#      data_pedido      modo_envio         nome_cliente segmento_cliente  \
# 7171  2016-01-04  Entrega padrão   Ana Júlia Monteiro              B2C
# 651   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 650   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 649   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 1576  2016-01-06  Entrega padrão      Marcelo Rezende              B2C
# ...          ...             ...                  ...              ...
# 796   2019-12-31  Entrega padrão           Lara Pinto              B2C
# 795   2019-12-31  Entrega padrão           Lara Pinto              B2C
# 794   2019-12-31  Entrega padrão           Lara Pinto              B2C
# 1151  2019-12-31  Entrega padrão         Cauê Martins              B2B
# 1152  2019-12-31  Entrega padrão         Cauê Martins              B2B
#
#               cidade            estado        regiao             departamento  \
# ...

# %%
df_meses['meses'] = df_meses['data_pedido'].dt.strftime('%Y - %b')
df.meses = df_meses.reset_index(drop=True)
df_meses
# Out:
# <ipython-input-32-c0440f40734a>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.meses = df_meses.reset_index(drop=True)
#      data_pedido      modo_envio         nome_cliente segmento_cliente  \
# 7171  2016-01-04  Entrega padrão   Ana Júlia Monteiro              B2C
# 651   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 650   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 649   2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 1576  2016-01-06  Entrega padrão      Marcelo Rezende              B2C
# ...          ...             ...                  ...              ...
# 796   2019-12-31  Entrega padrão           Lara Pinto              B2C
# 795   2019-12-31  Entrega padrão           Lara Pinto              B2C
# 794   2019-12-31  Entrega padrão           Lara Pinto              B2C
# ...

# %%
vendas_mensais = df_meses.pivot_table(index = 'departamento', columns = 'meses',values = 'quantidade', aggfunc='sum', sort = False)
vendas_mensais
# Out:
# meses                    2016 - Jan  2016 - Feb  2016 - Mar  2016 - Apr  \
# departamento
# Jardinagem e paisagismo         161          87         277         323
# Automotivo                       45          20          46         107
# Materiais de construção          60          23         102          69
#
# meses                    2016 - May  2016 - Jun  2016 - Jul  2016 - Aug  \
# departamento
# Jardinagem e paisagismo         270         273         348         339
# Automotivo                       81          83          91          95
# Materiais de construção          91         114         104         101
#
# meses                    2016 - Sep  2016 - Oct  ...  2019 - Mar  2019 - Apr  \
# departamento                                     ...
# Jardinagem e paisagismo         549         276  ...         458         415
# Automotivo                      154          85  ...         167          87
# ...

# %%
estilo_mensal = vendas_mensais.style
estilo_mensal
# Out:
# <style type="text/css">
# </style>
# <table id="T_95e8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >meses</th>
#       <th id="T_95e8c_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_95e8c_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_95e8c_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_95e8c_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_95e8c_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_95e8c_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_95e8c_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_95e8c_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_95e8c_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
# ...

# %%
# fixando a coluna ou index selecionada
estilo_mensal.set_sticky(axis ='index')
# Out:
# <style type="text/css">
# #T_95e8c thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_95e8c tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_95e8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >meses</th>
#       <th id="T_95e8c_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_95e8c_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_95e8c_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_95e8c_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_95e8c_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_95e8c_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
# ...

# %%
colunas = {
    'selector': '.col_headin',
    'props': 'font-weight: normal; font-family: Arial; color: #fff'
}

tables = {
    'selector': 'td, th',
    'props': 'text-align: left; color : #fff'
}

index = {
    'selector': '.index_name',
    'props': 'fontweight: bold; font-family: Arial; text-align: right; color: #fff'
}

estilo_mensal.set_table_styles([colunas, tables,index], overwrite= False)
# Out:
# <style type="text/css">
# #T_95e8c thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_95e8c tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_95e8c .col_headin {
#   font-weight: normal;
#   font-family: Arial;
#   color: #fff;
# }
# #T_95e8c td {
#   text-align: left;
#   color: #fff;
# }
# #T_95e8c  th {
#   text-align: left;
#   color: #fff;
# }
# #T_95e8c .index_name {
#   fontweight: bold;
#   font-family: Arial;
#   text-align: right;
#   color: #fff;
# }
# </style>
# <table id="T_95e8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >meses</th>
#       <th id="T_95e8c_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_95e8c_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
# ...

# %% [markdown]
# # Missão 5: Relatório de performance
#
# O relatório de performance é um documento muito importante para a empresa. Nele, todos que trabalham na loja podem entender como anda a empresa. Por conta disso, tabelas bem construídas são essenciais para mostrar os dados da melhor forma.
#
# Portanto, precisamos construir uma visualização que permita entender a **relação entre tipos de clientes e modo de envio de produtos de acordo com as vendas**. Com isso, será possível destacar no relatório qual o modo de envio e quais tipos de modo de envio mais geraram ganho em vendas.

# %%
df_cliente = df.pivot_table(index = 'segmento_cliente', columns = 'modo_envio',values = 'vendas',aggfunc = 'sum')
df_cliente
# Out:
# modo_envio         24 horas  Econômica  Entrega padrão  Envio rápido
# segmento_cliente
# B2B               217466.05  718462.52      1884740.78     602049.56
# B2C               182531.80  729176.13      2248286.96     498295.55

# %%
df_cliente['Total'] = df_cliente.sum(axis=1)
df_cliente
# Out:
# modo_envio         24 horas  Econômica  Entrega padrão  Envio rápido  \
# segmento_cliente
# B2B               217466.05  718462.52      1884740.78     602049.56
# B2C               182531.80  729176.13      2248286.96     498295.55
#
# modo_envio             Total
# segmento_cliente
# B2B               6845437.82
# B2C               7316580.88

# %%
df_cliente.loc['Total'] = df_cliente.sum()
df_cliente
# Out:
# modo_envio         24 horas   Econômica  Entrega padrão  Envio rápido  \
# segmento_cliente
# B2B               217466.05   718462.52      1884740.78     602049.56
# B2C               182531.80   729176.13      2248286.96     498295.55
# Total             799995.70  2895277.30      8266055.48    2200690.22
#
# modo_envio              Total
# segmento_cliente
# B2B                6845437.82
# B2C                7316580.88
# Total             28324037.40

# %%
compra_cliente = df_cliente.style.format('{:,.2f}')
compra_cliente
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a0c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_3a0c5_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_3a0c5_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_3a0c5_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_3a0c5_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
#       <th id="T_3a0c5_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
tabela = {
    'selector': 'td, th:not(.index_name)',
    'props': 'font-weight: normal; font-family: Arial; text-align: center; background-color: white'
}
index = {
    'selector':',index_name',
    'props': 'font-weight: normal; text-align: right; font-style: italic; color: #696969'
}

compra_cliente.set_table_styles([tabela,index])
# Out:
# <style type="text/css">
# #T_3a0c5 td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_3a0c5  th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_3a0c5  {
#   font-weight: normal;
#   text-align: right;
#   font-style: italic;
#   color: #696969;
# }
# #T_3a0c5 index_name {
#   font-weight: normal;
#   text-align: right;
#   font-style: italic;
#   color: #696969;
# }
# </style>
# <table id="T_3a0c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_3a0c5_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_3a0c5_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_3a0c5_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_3a0c5_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
# ...

# %%
compra_cliente.set_table_styles({
        'Total':[{
            'selector':'th',
            'props': 'border-top: 1px solid #fff'
        },
         {
            'selector':'td',
            'props': 'border-top: 1px solid #fff'
        }],
        'B2B':[{
            'selector':'th',
            'props': 'border-top: 1px solid #fff'
        },
         {
            'selector':'td',
            'props': 'border-top: 1px solid #fff'
        }]
  }, overwrite = False, axis=1)
# Out:
# <style type="text/css">
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #fff;
# }
# </style>
# <table id="T_3a0c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_3a0c5_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_3a0c5_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_3a0c5_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_3a0c5_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
# ...

# %%
compra_cliente.set_table_styles({
    'Total': [{
        'selector': '.true',
        'props': 'background-color: #ff0000'
    }]
}, overwrite=False, axis=0)
# Out:
# <style type="text/css">
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #D8D8D8;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #fff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #ffff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #ff0000;
# }
# #T_3a0c5 .true.col4 {
#   background-color: #ff0000;
# }
# </style>
# <table id="T_3a0c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_3a0c5_level0_col0" class="col_heading level0 col0" >24 horas</th>
# ...

# %%
cores_coluna = pd.DataFrame(['false','true','false'],index= df_cliente['Total'].index, columns = ['Total'])
cores_coluna
# Out:
#                   Total
# segmento_cliente
# B2B               false
# B2C                true
# Total             false

# %%
compra_cliente.set_td_classes(cores_coluna)
# Out:
# <style type="text/css">
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_3a0c5 th.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row2 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 th.row0 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 td.row0 {
#   border-top: 1px solid #fff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #D8D8D8;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #fff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #ffff;
# }
# #T_3a0c5 .true.col4 {
#   backgound-color: #ff0000;
# }
# #T_3a0c5 .true.col4 {
#   background-color: #ff0000;
# }
# </style>
# <table id="T_3a0c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_3a0c5_level0_col0" class="col_heading level0 col0" >24 horas</th>
# ...

# %%
import pandas as pd
import numpy as np

dados = pd.DataFrame({'ID': [1204, 3018, 9963, 1005, 5627],
                   'Idade': [np.nan, 32, 19, np.nan, 38],
                   'Salário': [3500.00, 4200.50, 2800.00, 5700.25, 4900.75]})


s_nan = dados.style.format({'Idade':'{:.0f}','Salário':'{:,.2f}'})\
                   .highlight_null(color='#F79747')
s_nan
# Out:
# <style type="text/css">
# #T_7a27e_row0_col1, #T_7a27e_row3_col1 {
#   background-color: #F79747;
# }
# </style>
# <table id="T_7a27e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a27e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_7a27e_level0_col1" class="col_heading level0 col1" >Idade</th>
#       <th id="T_7a27e_level0_col2" class="col_heading level0 col2" >Salário</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a27e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a27e_row0_col0" class="data row0 col0" >1204</td>
#       <td id="T_7a27e_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_7a27e_row0_col2" class="data row0 col2" >3,500.00</td>
#     </tr>
#     <tr>
#       <th id="T_7a27e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a27e_row1_col0" class="data row1 col0" >3018</td>
# ...

# %%
## Definir os limites superior e inferior
limite_superior = 5000.0
# O limite inferior é especificado através de uma Series que informa qual a coluna que terá a aplicação da função
limite_inferior = pd.Series([4000.0], index=['Salário'])

## Aplicar a estilização com highlight_between
s_bet = dados.style.format({'Idade':'{:.0f}','Salário':'{:,.2f}'})\
                   .highlight_between(left=limite_inferior, right=limite_superior,
                                      axis=1, color='#94B2D7')
s_bet
# Out:
# <style type="text/css">
# #T_c7243_row1_col2, #T_c7243_row4_col2 {
#   background-color: #94B2D7;
# }
# </style>
# <table id="T_c7243" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7243_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c7243_level0_col1" class="col_heading level0 col1" >Idade</th>
#       <th id="T_c7243_level0_col2" class="col_heading level0 col2" >Salário</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7243_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7243_row0_col0" class="data row0 col0" >1204</td>
#       <td id="T_c7243_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_c7243_row0_col2" class="data row0 col2" >3,500.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7243_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7243_row1_col0" class="data row1 col0" >3018</td>
# ...

# %%
# A exportação de tabelas em diferentes formatos é uma tarefa muito comum e importante na análise de dados e na produção de relatórios.
# O Pandas oferece diversas funções para exportar um objeto Styler para diferentes tipos de arquivos.

# Podemos exportar um objeto Styler para diferentes formatos, como HTML, Excel e LaTeX, a partir das seguintes funções:

# to_html(): essa função permite exportar uma tabela formatada em HTML.
# A função recebe vários parâmetros para personalizar a formatação do arquivo HTML, como o título da página, as bordas da tabela, o estilo CSS e o encoding.
# to_excel(): essa função permite exportar uma tabela para um arquivo Excel.
# É possível personalizar a planilha de destino, as opções de formatação, os nomes das abas e outras configurações.
# to_latex(): essa função permite exportar uma tabela para um arquivo LaTeX.
# É possível personalizar o estilo de formatação, as opções de posicionamento, as configurações de largura e outras opções.
# Vamos transformar o DataFrame que lista os gêneros de filmes mais bem avaliados em:

# um arquivo HTML;
# um arquivo Excel;
# e um arquivo LaTeX.
import pandas as pd

# DataFrame com filmes bem avaliados
dados = {
    'Gênero': ['Drama', 'Comédia', 'Ação', 'Ficção Científica', 'Terror'],
    'Nota Média': [4.5, 4.3, 4.2, 4.1, 3.8],
    'Quantidade de Avaliações': [1500, 1200, 1000, 800, 600]
}

df_filmes = pd.DataFrame(dados)

# Adiciona um rank de popularidade baseado no valor das avaliações
df_filmes['Rank'] = df_filmes['Quantidade de Avaliações'].rank(method='dense', ascending=False).astype(int)

# Define a coluna 'Rank' como índice do DataFrame
df_filmes.set_index('Rank', inplace=True)
# Objeto style
s_filme = df_filmes.style

# Criar um arquivo HTML
s_filme.to_html('estilo_html.html', index = False)

# Criar um arquivo Excel
s_filme.to_excel('estilo_xlsx.xlsx', engine='openpyxl')

# Criar um arquivo LaTeX
with open('estilo_latex.tex', 'w') as f:
  f.write(s_filme.to_latex())
