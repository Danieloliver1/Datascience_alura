# %%
#import streamlit as st
import requests
import pandas as pd
import plotly.express as px

# %%
url = 'https://labdados.com/produtos'

# %%
response = requests.get(url)
dados = pd.DataFrame.from_dict(response.json())
dados['Data da Compra'] = pd.to_datetime(dados['Data da Compra'], format='%d/%m/%Y')

# %%
dados.head()
# Out:
#                     Produto   Categoria do Produto  Preço     Frete  \
# 0       Modelagem preditiva                 livros  92.45  5.609697
# 1  Iniciando em programação                 livros  43.84  0.000000
# 2                  Pandeiro  instrumentos musicais  87.18  2.226512
# 3            Corda de pular        esporte e lazer  13.65  1.257926
# 4            Dinossauro Rex             brinquedos  28.32  2.039059
#
#   Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0     2020-01-01      Thiago Silva              BA                    1
# 1     2020-01-01  Mariana Ferreira              SP                    5
# 2     2020-01-01      Thiago Silva              RJ                    4
# 3     2020-01-01    Camila Ribeiro              RJ                    4
# 4     2020-01-01     Juliana Costa              RJ                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -13.29 -41.71
# ...

# %%
dados[dados['Protudo']==f'{produtos}']
# Out:
#                   Produto Categoria do Produto   Preço      Frete  \
# 0     Modelagem preditiva               livros   92.45   5.609697
# 57    Modelagem preditiva               livros   70.49   1.337820
# 87    Modelagem preditiva               livros   71.64   1.399054
# 188   Modelagem preditiva               livros  105.99   3.228088
# 209   Modelagem preditiva               livros  101.54  14.501086
# ...                   ...                  ...     ...        ...
# 9307  Modelagem preditiva               livros   98.96   5.552448
# 9331  Modelagem preditiva               livros   70.68   1.347936
# 9347  Modelagem preditiva               livros  108.34   6.051905
# 9381  Modelagem preditiva               livros  109.17   6.701389
# 9393  Modelagem preditiva               livros   94.89   5.578872
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0        2020-01-01      Thiago Silva              BA                    1
# ...

# %%
dados.query(" `Produto` == 'Modelagem preditiva' and `Data da Compra` == '2022-07-01' and `Preço` >= 70.49 ")
# Out:
#                  Produto Categoria do Produto   Preço     Frete  \
# 188  Modelagem preditiva               livros  105.99  3.228088
#
#     Data da Compra      Vendedor Local da compra  Avaliação da compra  \
# 188     2022-07-01  Thiago Silva              SP                    1
#
#     Tipo de pagamento  Quantidade de parcelas    lat    lon
# 188    cartao_credito                       4 -22.19 -48.79

# %%
dados.query(f" `Produto` == '{produtos}' and `Data da Compra` == '{data_compra}' and `Preço` >= {preco}")

# %%
consulta = []
produto = 'Modelagem preditiva'
data_da_compra = '2022-07-01'
preco_minimo = 70.49

if produto =='':
  filtrar_produto = False
else:
  filtrar_produto = True

if filtrar_produto:
  consulta.append(f" `Produto` == '{produto}'")
consulta.append(f"`Data da Compra` == '{data_da_compra}'")
consulta.append(f"`Preço` >= {preco_minimo}")

consulta_str = 'and'.join(consulta)

dados.query(consulta_str)

#dados.query(f" `Produto` == '{produtos}' and `Data da Compra` == '{data_compra}' and `Preço` >= {preco}")
# Out:
#                  Produto Categoria do Produto   Preço     Frete  \
# 188  Modelagem preditiva               livros  105.99  3.228088
#
#     Data da Compra      Vendedor Local da compra  Avaliação da compra  \
# 188     2022-07-01  Thiago Silva              SP                    1
#
#     Tipo de pagamento  Quantidade de parcelas    lat    lon
# 188    cartao_credito                       4 -22.19 -48.79

# %%
int(dados['Frete'].max())
# Out:
# 216

# %%
dados['Avaliação da compra'].max()
# Out:
# 5

# %%
list(dados.columns)
# Out:
# ['Produto',
#  'Categoria do Produto',
#  'Preço',
#  'Frete',
#  'Data da Compra',
#  'Vendedor',
#  'Local da compra',
#  'Avaliação da compra',
#  'Tipo de pagamento',
#  'Quantidade de parcelas',
#  'lat',
#  'lon']

# %%
dados.to_excel('teste.xlsx')

# %%
def converte_excel(df, nome_arquivo):
    return df.to_excel(nome_arquivo, index=False)  # .encode('utf-8')

# %%
converte_excel(dados
